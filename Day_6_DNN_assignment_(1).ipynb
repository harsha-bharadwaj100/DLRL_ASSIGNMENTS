# %% [markdown]
# ## DNN Example for Fashion MNIST Dataset

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load Fashion MNIST Dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Class labels
class_names = ['T-shirt', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
# Plot label distribution
def plot_label_distribution(labels, class_names):
    plt.figure(figsize=(10, 5))
    sns.countplot(x=labels, hue=labels, palette="viridis", legend=False)
    plt.xticks(np.arange(10), class_names, rotation=45)
    plt.title("Distribution of Fashion MNIST Classes")
    plt.xlabel("Class Name")
    plt.ylabel("Count")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Plot sample images
def plot_fashion_mnist(images, labels, class_names, rows=5, cols=5):
    plt.figure(figsize=(2 * cols, 2.5 * rows))
    for i in range(rows * cols):
        plt.subplot(rows, cols, i + 1)
        plt.imshow(images[i], cmap='gray')
        plt.title(class_names[labels[i]], fontsize=9)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_label_distribution(y_train, class_names)
plot_fashion_mnist(x_train, y_train, class_names)

# %%
# Normalize pixel values
x_train = x_train / 255.0
x_test = x_test / 255.0

# Flatten input images
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# %%
def create_model():
    initializer = tf.keras.initializers.RandomNormal(mean=0.0, stddev=0.05)
    model = models.Sequential([
        layers.Input(shape=(784,)),
        layers.Dense(512, kernel_initializer=initializer),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.4),

        layers.Dense(256, kernel_initializer=initializer),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.3),

        layers.Dense(128, kernel_initializer=initializer),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.2),

        layers.Dense(64, kernel_initializer=initializer),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dropout(0.1),

        layers.Dense(10, activation='softmax')
    ])
    return model

# %%
model = create_model()
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 578,890 (2.21 MB)
#  Trainable params: 576,970 (2.20 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Train the model
history = model.fit(x_train, y_train, validation_split=0.2,
                    epochs=20, batch_size=128, verbose=2)
# Out:
# Epoch 1/20
# 375/375 - 10s - 27ms/step - accuracy: 0.7782 - loss: 0.6426 - val_accuracy: 0.8513 - val_loss: 0.4159
# Epoch 2/20
# 375/375 - 5s - 12ms/step - accuracy: 0.8425 - loss: 0.4442 - val_accuracy: 0.8606 - val_loss: 0.3925
# Epoch 3/20
# 375/375 - 1s - 4ms/step - accuracy: 0.8565 - loss: 0.4036 - val_accuracy: 0.8692 - val_loss: 0.3510
# Epoch 4/20
# 375/375 - 3s - 8ms/step - accuracy: 0.8634 - loss: 0.3779 - val_accuracy: 0.8721 - val_loss: 0.3503
# Epoch 5/20
# 375/375 - 2s - 5ms/step - accuracy: 0.8712 - loss: 0.3576 - val_accuracy: 0.8762 - val_loss: 0.3376
# Epoch 6/20
# 375/375 - 2s - 6ms/step - accuracy: 0.8768 - loss: 0.3438 - val_accuracy: 0.8622 - val_loss: 0.3919
# Epoch 7/20
# 375/375 - 1s - 4ms/step - accuracy: 0.8788 - loss: 0.3332 - val_accuracy: 0.8808 - val_loss: 0.3299
# Epoch 8/20
# 375/375 - 1s - 4ms/step - accuracy: 0.8848 - loss: 0.3193 - val_accuracy: 0.8780 - val_loss: 0.3325
# Epoch 9/20
# 375/375 - 3s - 7ms/step - accuracy: 0.8876 - loss: 0.3102 - val_accuracy: 0.8717 - val_loss: 0.3578
# Epoch 10/20
# 375/375 - 3s - 7ms/step - accuracy: 0.8890 - loss: 0.3021 - val_accuracy: 0.8898 - val_loss: 0.3038
# Epoch 11/20
# 375/375 - 2s - 6ms/step - accuracy: 0.8933 - loss: 0.2931 - val_accuracy: 0.8786 - val_loss: 0.3365
# Epoch 12/20
# 375/375 - 3s - 7ms/step - accuracy: 0.8968 - loss: 0.2875 - val_accuracy: 0.8902 - val_loss: 0.3077
# Epoch 13/20
# 375/375 - 3s - 7ms/step - accuracy: 0.8990 - loss: 0.2768 - val_accuracy: 0.8832 - val_loss: 0.3159
# Epoch 14/20
# 375/375 - 1s - 4ms/step - accuracy: 0.9004 - loss: 0.2690 - val_accuracy: 0.8780 - val_loss: 0.3464
# Epoch 15/20
# 375/375 - 1s - 4ms/step - accuracy: 0.9028 - loss: 0.2654 - val_accuracy: 0.8825 - val_loss: 0.3203
# Epoch 16/20
# 375/375 - 3s - 8ms/step - accuracy: 0.9044 - loss: 0.2602 - val_accuracy: 0.8852 - val_loss: 0.3217
# Epoch 17/20
# 375/375 - 1s - 4ms/step - accuracy: 0.9067 - loss: 0.2542 - val_accuracy: 0.8832 - val_loss: 0.3330
# Epoch 18/20
# 375/375 - 2s - 5ms/step - accuracy: 0.9082 - loss: 0.2512 - val_accuracy: 0.8909 - val_loss: 0.3006
# Epoch 19/20
# 375/375 - 2s - 5ms/step - accuracy: 0.9114 - loss: 0.2433 - val_accuracy: 0.8929 - val_loss: 0.2983
# Epoch 20/20
# 375/375 - 2s - 6ms/step - accuracy: 0.9120 - loss: 0.2416 - val_accuracy: 0.8890 - val_loss: 0.3161

# %%
# Plot Training History
def plot_history(history):
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Loss Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)

# %%
# Evaluate Model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# Test Accuracy: 0.8794

# %%
# Predict and visualize sample results
def show_predictions(model, x_test, y_test):
    preds = model.predict(x_test)
    pred_classes = np.argmax(preds, axis=1)

    plt.figure(figsize=(12, 6))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
        plt.title(f"True: {class_names[y_test[i]]}\nPred: {class_names[pred_classes[i]]}")
        plt.axis('off')
    plt.tight_layout()
    plt.show()

show_predictions(model, x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step

# %% [markdown]
# ## ResNet (DNN) Example for Fashion MNIST Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, Add, Activation, Flatten
from tensorflow.keras.utils import to_categorical

# Load and preprocess data
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Flatten the images for DNN
x_train_flat = x_train.reshape(-1, 28*28)
x_test_flat = x_test.reshape(-1, 28*28)

# Visualize some samples
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[np.argmax(y_train[i])])
plt.show()

# %%
# Standard DNN Model
def create_dnn():
    inputs = Input(shape=(784,))
    x = Dense(256, activation='relu')(inputs)
    x = Dense(256, activation='relu')(x)
    x = Dense(128, activation='relu')(x)
    x = Dense(64, activation='relu')(x)
    outputs = Dense(10, activation='softmax')(x)
    return Model(inputs, outputs)

# %%
# ResNet-style DNN Model (with residual connections) enhanced
from tensorflow.keras.layers import Dense, Input, Add, Activation, BatchNormalization, Dropout
from tensorflow.keras.models import Model

def residual_block(x, units, dropout_rate=0.3):
    shortcut = Dense(units)(x)

    x = Dense(units)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    x = Dense(units)(x)
    x = BatchNormalization()(x)

    x = Add()([shortcut, x])
    x = Activation('relu')(x)

    return x

def create_resnet_dnn():
    inputs = Input(shape=(784,))

    x = Dense(512)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.3)(x)

    # Residual Blocks
    x = residual_block(x, 784)
    x = residual_block(x, 625)
    x = residual_block(x, 512)
    x = residual_block(x, 441)
    x = residual_block(x, 324)
    x = residual_block(x, 225)
    x = residual_block(x, 144)
    x = residual_block(x, 100)
    x = residual_block(x, 81)
    x = residual_block(x, 64)
    x = residual_block(x, 32)

    outputs = Dense(10, activation='softmax')(x)

    return Model(inputs, outputs)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Create and compile models
dnn_model = create_dnn()
dnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
resnet_model = create_resnet_dnn()
resnet_model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# LR scheduler
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
# Early Stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, min_delta=0.001, restore_best_weights=True, verbose=1)

# %%
# Train models
print("Training Standard DNN...")
dnn_history = dnn_model.fit(x_train_flat, y_train,
                            epochs=10,
                            batch_size=128,
                            validation_split=0.2,
                            verbose=1)
# Evaluate on test set
dnn_test_loss, dnn_test_acc = dnn_model.evaluate(x_test_flat, y_test, verbose=0)
print(f"Standard DNN Test Accuracy: {dnn_test_acc:.4f}")
# Out:
# Training Standard DNN...
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7348 - loss: 0.7570 - val_accuracy: 0.8491 - val_loss: 0.4204
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8594 - loss: 0.3877 - val_accuracy: 0.8625 - val_loss: 0.3762
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8722 - loss: 0.3444 - val_accuracy: 0.8742 - val_loss: 0.3544
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8847 - loss: 0.3149 - val_accuracy: 0.8735 - val_loss: 0.3517
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8898 - loss: 0.2938 - val_accuracy: 0.8824 - val_loss: 0.3329
# Epoch 6/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8937 - loss: 0.2779 - val_accuracy: 0.8817 - val_loss: 0.3274
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8997 - loss: 0.2642 - val_accuracy: 0.8836 - val_loss: 0.3245
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9050 - loss: 0.2509 - val_accuracy: 0.8878 - val_loss: 0.3159
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9097 - loss: 0.2390 - val_accuracy: 0.8842 - val_loss: 0.3275
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9142 - loss: 0.2283 - val_accuracy: 0.8873 - val_loss: 0.3219
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9162 - loss: 0.2211 - val_accuracy: 0.8905 - val_loss: 0.3232
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9193 - loss: 0.2135 - val_accuracy: 0.8869 - val_loss: 0.3202
# Epoch 13/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9222 - loss: 0.2025 - val_accuracy: 0.8903 - val_loss: 0.3340
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9269 - loss: 0.1941 - val_accuracy: 0.8932 - val_loss: 0.3275
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9301 - loss: 0.1848 - val_accuracy: 0.8945 - val_loss: 0.3167
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9294 - loss: 0.1844 - val_accuracy: 0.8947 - val_loss: 0.3368
# Epoch 17/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9341 - loss: 0.1778 - val_accuracy: 0.8862 - val_loss: 0.3433
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9344 - loss: 0.1703 - val_accuracy: 0.8936 - val_loss: 0.3339
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9396 - loss: 0.1600 - val_accuracy: 0.8951 - val_loss: 0.3438
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9406 - loss: 0.1572 - val_accuracy: 0.8913 - val_loss: 0.3426
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9434 - loss: 0.1499 - val_accuracy: 0.8959 - val_loss: 0.3474
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9463 - loss: 0.1409 - val_accuracy: 0.8955 - val_loss: 0.3408
# Epoch 23/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9452 - loss: 0.1426 - val_accuracy: 0.8976 - val_loss: 0.3347
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9487 - loss: 0.1329 - val_accuracy: 0.8979 - val_loss: 0.3653
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9493 - loss: 0.1303 - val_accuracy: 0.8882 - val_loss: 0.3897
# Epoch 26/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9487 - loss: 0.1333 - val_accuracy: 0.9001 - val_loss: 0.3727
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9535 - loss: 0.1213 - val_accuracy: 0.8973 - val_loss: 0.3806
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9527 - loss: 0.1231 - val_accuracy: 0.8881 - val_loss: 0.4003
# Epoch 29/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9560 - loss: 0.1123 - val_accuracy: 0.8951 - val_loss: 0.3996
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9566 - loss: 0.1110 - val_accuracy: 0.8966 - val_loss: 0.4021
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9605 - loss: 0.1036 - val_accuracy: 0.8969 - val_loss: 0.3758
# Epoch 32/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9584 - loss: 0.1075 - val_accuracy: 0.8942 - val_loss: 0.4335
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9624 - loss: 0.0986 - val_accuracy: 0.8974 - val_loss: 0.4097
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9631 - loss: 0.0952 - val_accuracy: 0.8907 - val_loss: 0.4489
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9667 - loss: 0.0911 - val_accuracy: 0.8938 - val_loss: 0.4899
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9626 - loss: 0.0949 - val_accuracy: 0.8964 - val_loss: 0.4600
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9666 - loss: 0.0856 - val_accuracy: 0.8963 - val_loss: 0.4819
# Epoch 38/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9662 - loss: 0.0857 - val_accuracy: 0.8950 - val_loss: 0.4272
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9672 - loss: 0.0849 - val_accuracy: 0.8932 - val_loss: 0.4825
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9668 - loss: 0.0866 - val_accuracy: 0.8950 - val_loss: 0.4762
# Epoch 41/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9703 - loss: 0.0782 - val_accuracy: 0.8908 - val_loss: 0.5211
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9706 - loss: 0.0763 - val_accuracy: 0.8959 - val_loss: 0.5048
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9717 - loss: 0.0747 - val_accuracy: 0.8913 - val_loss: 0.5104
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9682 - loss: 0.0813 - val_accuracy: 0.8932 - val_loss: 0.4857
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9702 - loss: 0.0758 - val_accuracy: 0.8960 - val_loss: 0.5031
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9735 - loss: 0.0675 - val_accuracy: 0.8962 - val_loss: 0.5726
# Epoch 47/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9743 - loss: 0.0682 - val_accuracy: 0.8893 - val_loss: 0.5307
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9718 - loss: 0.0767 - val_accuracy: 0.8973 - val_loss: 0.4922
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9767 - loss: 0.0623 - val_accuracy: 0.8910 - val_loss: 0.5244
# Epoch 50/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9749 - loss: 0.0636 - val_accuracy: 0.8940 - val_loss: 0.5189
# Standard DNN Test Accuracy: 0.8898

# %%
print("Training ResNet Style DNN...")
resnet_history = resnet_model.fit(x_train_flat, y_train,
                                  epochs=50,
                                  batch_size=128,
                                  validation_split=0.2,
                                  callbacks=[lr_scheduler],
                                  verbose=1)
resnet_test_loss, resnet_test_acc = resnet_model.evaluate(x_test_flat, y_test, verbose=0)
print(f"ResNet-style DNN Test Accuracy: {resnet_test_acc:.4f}")
# Out:
# Training ResNet Style DNN...
# Epoch 1/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 44s 26ms/step - accuracy: 0.5344 - loss: 1.2732 - val_accuracy: 0.8140 - val_loss: 0.5322 - learning_rate: 0.0010
# Epoch 2/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8242 - loss: 0.4878 - val_accuracy: 0.8522 - val_loss: 0.4196 - learning_rate: 0.0010
# Epoch 3/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8461 - loss: 0.4291 - val_accuracy: 0.8608 - val_loss: 0.3996 - learning_rate: 0.0010
# Epoch 4/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8584 - loss: 0.3965 - val_accuracy: 0.8561 - val_loss: 0.4162 - learning_rate: 0.0010
# Epoch 5/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8632 - loss: 0.3817 - val_accuracy: 0.8542 - val_loss: 0.4236 - learning_rate: 0.0010
# Epoch 6/50
# 374/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8729 - loss: 0.3581
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.8728 - loss: 0.3581 - val_accuracy: 0.8482 - val_loss: 0.4218 - learning_rate: 0.0010
# Epoch 7/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8877 - loss: 0.3098 - val_accuracy: 0.8873 - val_loss: 0.3147 - learning_rate: 5.0000e-04
# Epoch 8/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8932 - loss: 0.2900 - val_accuracy: 0.8795 - val_loss: 0.3301 - learning_rate: 5.0000e-04
# Epoch 9/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.8956 - loss: 0.2855 - val_accuracy: 0.8723 - val_loss: 0.3841 - learning_rate: 5.0000e-04
# Epoch 10/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.8994 - loss: 0.2783 - val_accuracy: 0.8862 - val_loss: 0.3135 - learning_rate: 5.0000e-04
# Epoch 11/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step - accuracy: 0.9021 - loss: 0.2693 - val_accuracy: 0.8864 - val_loss: 0.3314 - learning_rate: 5.0000e-04
# Epoch 12/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9029 - loss: 0.2672 - val_accuracy: 0.8848 - val_loss: 0.3202 - learning_rate: 5.0000e-04
# Epoch 13/50
# 374/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9059 - loss: 0.2622
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9059 - loss: 0.2622 - val_accuracy: 0.8820 - val_loss: 0.3387 - learning_rate: 5.0000e-04
# Epoch 14/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9128 - loss: 0.2342 - val_accuracy: 0.8965 - val_loss: 0.2989 - learning_rate: 2.5000e-04
# Epoch 15/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9215 - loss: 0.2094 - val_accuracy: 0.8942 - val_loss: 0.3053 - learning_rate: 2.5000e-04
# Epoch 16/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9239 - loss: 0.2029 - val_accuracy: 0.8938 - val_loss: 0.3014 - learning_rate: 2.5000e-04
# Epoch 17/50
# 371/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9271 - loss: 0.1960
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9271 - loss: 0.1961 - val_accuracy: 0.8970 - val_loss: 0.3113 - learning_rate: 2.5000e-04
# Epoch 18/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9327 - loss: 0.1794 - val_accuracy: 0.8999 - val_loss: 0.3026 - learning_rate: 1.2500e-04
# Epoch 19/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9338 - loss: 0.1710 - val_accuracy: 0.9010 - val_loss: 0.3040 - learning_rate: 1.2500e-04
# Epoch 20/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9388 - loss: 0.1659 - val_accuracy: 0.9018 - val_loss: 0.2878 - learning_rate: 1.2500e-04
# Epoch 21/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9427 - loss: 0.1576 - val_accuracy: 0.9004 - val_loss: 0.3042 - learning_rate: 1.2500e-04
# Epoch 22/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9421 - loss: 0.1545 - val_accuracy: 0.9001 - val_loss: 0.3006 - learning_rate: 1.2500e-04
# Epoch 23/50
# 374/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9436 - loss: 0.1531
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9436 - loss: 0.1531 - val_accuracy: 0.9015 - val_loss: 0.3033 - learning_rate: 1.2500e-04
# Epoch 24/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9487 - loss: 0.1382 - val_accuracy: 0.9043 - val_loss: 0.3200 - learning_rate: 6.2500e-05
# Epoch 25/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9498 - loss: 0.1320 - val_accuracy: 0.9024 - val_loss: 0.3127 - learning_rate: 6.2500e-05
# Epoch 26/50
# 371/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9537 - loss: 0.1270
# Epoch 26: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9537 - loss: 0.1271 - val_accuracy: 0.9060 - val_loss: 0.3087 - learning_rate: 6.2500e-05
# Epoch 27/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9541 - loss: 0.1202 - val_accuracy: 0.9043 - val_loss: 0.3208 - learning_rate: 3.1250e-05
# Epoch 28/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9578 - loss: 0.1131 - val_accuracy: 0.9052 - val_loss: 0.3218 - learning_rate: 3.1250e-05
# Epoch 29/50
# 373/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9572 - loss: 0.1135
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9572 - loss: 0.1135 - val_accuracy: 0.9060 - val_loss: 0.3205 - learning_rate: 3.1250e-05
# Epoch 30/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9586 - loss: 0.1128 - val_accuracy: 0.9063 - val_loss: 0.3236 - learning_rate: 1.5625e-05
# Epoch 31/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9578 - loss: 0.1122 - val_accuracy: 0.9061 - val_loss: 0.3225 - learning_rate: 1.5625e-05
# Epoch 32/50
# 372/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9581 - loss: 0.1128
# Epoch 32: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9581 - loss: 0.1127 - val_accuracy: 0.9055 - val_loss: 0.3245 - learning_rate: 1.5625e-05
# Epoch 33/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9602 - loss: 0.1053 - val_accuracy: 0.9066 - val_loss: 0.3254 - learning_rate: 7.8125e-06
# Epoch 34/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9613 - loss: 0.1024 - val_accuracy: 0.9072 - val_loss: 0.3306 - learning_rate: 7.8125e-06
# Epoch 35/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9611 - loss: 0.1022
# Epoch 35: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9611 - loss: 0.1022 - val_accuracy: 0.9069 - val_loss: 0.3303 - learning_rate: 7.8125e-06
# Epoch 36/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9591 - loss: 0.1087 - val_accuracy: 0.9072 - val_loss: 0.3295 - learning_rate: 3.9063e-06
# Epoch 37/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9614 - loss: 0.1022 - val_accuracy: 0.9065 - val_loss: 0.3302 - learning_rate: 3.9063e-06
# Epoch 38/50
# 370/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9628 - loss: 0.1003
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9627 - loss: 0.1004 - val_accuracy: 0.9079 - val_loss: 0.3316 - learning_rate: 3.9063e-06
# Epoch 39/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9631 - loss: 0.1007 - val_accuracy: 0.9074 - val_loss: 0.3315 - learning_rate: 1.9531e-06
# Epoch 40/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9605 - loss: 0.1024 - val_accuracy: 0.9072 - val_loss: 0.3319 - learning_rate: 1.9531e-06
# Epoch 41/50
# 371/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9619 - loss: 0.1051
# Epoch 41: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9619 - loss: 0.1050 - val_accuracy: 0.9072 - val_loss: 0.3324 - learning_rate: 1.9531e-06
# Epoch 42/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9598 - loss: 0.1055 - val_accuracy: 0.9065 - val_loss: 0.3328 - learning_rate: 9.7656e-07
# Epoch 43/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.9620 - loss: 0.1036 - val_accuracy: 0.9069 - val_loss: 0.3329 - learning_rate: 9.7656e-07
# Epoch 44/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9629 - loss: 0.1022
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9629 - loss: 0.1022 - val_accuracy: 0.9070 - val_loss: 0.3330 - learning_rate: 9.7656e-07
# Epoch 45/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9623 - loss: 0.1004 - val_accuracy: 0.9072 - val_loss: 0.3329 - learning_rate: 4.8828e-07
# Epoch 46/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9624 - loss: 0.1022 - val_accuracy: 0.9072 - val_loss: 0.3335 - learning_rate: 4.8828e-07
# Epoch 47/50
# 372/375 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9620 - loss: 0.1012
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9620 - loss: 0.1012 - val_accuracy: 0.9070 - val_loss: 0.3328 - learning_rate: 4.8828e-07
# Epoch 48/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9617 - loss: 0.1026 - val_accuracy: 0.9070 - val_loss: 0.3330 - learning_rate: 2.4414e-07
# Epoch 49/50
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9612 - loss: 0.1024 - val_accuracy: 0.9072 - val_loss: 0.3333 - learning_rate: 2.4414e-07
# Epoch 50/50
# 374/375 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9612 - loss: 0.1051
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.9612 - loss: 0.1051 - val_accuracy: 0.9068 - val_loss: 0.3338 - learning_rate: 2.4414e-07
# ResNet-style DNN Test Accuracy: 0.9034

# %%
# Plot training history
def plot_history(history, title):
    plt.figure(figsize=(12, 4))
    plt.suptitle(title)

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss')
    plt.legend()

    plt.show()

# %%
plot_history(dnn_history, 'Standard DNN Training')
plot_history(resnet_history, 'ResNet-style DNN Training')

# %%
# Make predictions and visualize some results
def plot_predictions(model, x_test, y_test, num_images=5):
    predictions = model.predict(x_test)
    plt.figure(figsize=(22, 3*num_images))
    for i in range(num_images):
        plt.subplot(num_images, 1, i+1)
        plt.imshow(x_test[i].reshape(28, 28), cmap=plt.cm.binary)
        pred_label = np.argmax(predictions[i])
        true_label = np.argmax(y_test[i])
        color = 'green' if pred_label == true_label else 'red'
        plt.xlabel(f"Predicted: {class_names[pred_label]} (True: {class_names[true_label]})", color=color)
    plt.show()

print("\nStandard DNN Predictions:")
plot_predictions(dnn_model, x_test_flat, y_test)

print("\nResNet-style DNN Predictions:")
plot_predictions(resnet_model, x_test_flat, y_test)
# Out:
# Standard DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# ResNet-style DNN Predictions:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step
